# %%
beat = 444
nodes = 50
steps = 16

fileout2 = open('Documents\\xLights\\CandyCaneLane.xsq','w')
fileout2.write('''<?xml version="1.0" encoding="UTF-8"?>
<xsequence BaseChannel="0" ChanCtrlBasic="0" ChanCtrlColor="0" FixedPointTiming="1" ModelBlending="true">
  <head>
    <version>2020.53</version>
    <author/>
    <author-email/>
    <author-website/>
    <song/>
    <artist/>
    <album/>
    <MusicURL/>
    <comment/>
    <sequenceTiming>25 ms</sequenceTiming>
    <sequenceType>Media</sequenceType>
    <mediaFile>C:\\Users\\doug\\Downloads\\02 - Candy Cane Lane.mp3</mediaFile>
    <sequenceDuration>212.386</sequenceDuration>
    <imageDir/>
  </head>
  <nextid>1</nextid>
  <Jukebox/>
  <ColorPalettes>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette2=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette5=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette8=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette3=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette7=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#8000FF,C_CHECKBOX_Palette8=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette4=1</ColorPalette>
    <ColorPalette>C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette1=1</ColorPalette>
  </ColorPalettes>
  <EffectDB>
    <Effect></Effect>
  </EffectDB>
  <DataLayers>
    <DataLayer lor_params="596" channel_offset="0" num_channels="0" num_frames="0" data="&lt;rendered: erase-mode&gt;" source="&lt;auto-generated&gt;" name="Nutcracker"/>
  </DataLayers>
  <DisplayElements>
    <Element collapsed="0" type="timing" name="New Timing" visible="1" views="Master View" active="1"/>
    <Element collapsed="0" type="model" name="TestGroup" visible="1"/>
    <Element collapsed="0" type="model" name="LineGroup" visible="1"/>
    <Element collapsed="0" type="model" name="individual" visible="1"/>
    <Element collapsed="0" type="model" name="Testing" visible="1"/>
  </DisplayElements>
  <ElementEffects>
    <Element type="timing" name="New Timing">
      <EffectLayer/>
    </Element>
    <Element type="model" name="TestGroup">
      <EffectLayer/>
    </Element>
    <Element type="model" name="LineGroup">
      <EffectLayer/>
    </Element>
    <Element type="model" name="individual">
      <EffectLayer/>
    </Element>
    <Element type="model" name="Testing">
      <EffectLayer/>
      <Strand index="0">''')

nodejson = {}
nodejson['model'] = 'Testing'
for i in range(nodes):
    group = int(i/nodecnt)
    fileout2.write('<Node index="{}">'.format(str(i)))
    for x in range(steps):
        palette = "0"
        nodecnt = nodes/steps
        if not group % 2 == x % 2: palette = "7"
        if i <= int(round(nodecnt*(x+1))):
            nname = "On"
        else:
            nname = "Off"
        fileout2.write('<Effect ref="0" name="{3}" id="{0}" startTime="{1}" endTime="{2}" palette="{4}"/>'.format(
            str(x),
            str(int(x*beat)),
            str(int((x+1)*beat)),
            nname,
            palette
        ))
    fileout2.write('</Node>')

fileout2.write('''</Strand>
    </Element>
  </ElementEffects>
  <lastView>0</lastView>
  <TimingTags>
    <Tag number="0" position="-1"/>
    <Tag number="1" position="-1"/>
    <Tag number="2" position="-1"/>
    <Tag number="3" position="-1"/>
    <Tag number="4" position="-1"/>
    <Tag number="5" position="-1"/>
    <Tag number="6" position="-1"/>
    <Tag number="7" position="-1"/>
    <Tag number="8" position="-1"/>
    <Tag number="9" position="-1"/>
  </TimingTags>
</xsequence>''')
fileout2.close()

# %%
import csv
import json
import random
from xml.etree import ElementTree
from xml.etree.ElementTree import Element, SubElement, Comment, tostring
import datetime
import xml.dom.minidom as xdom
#from ElementTree_pretty import prettify

beat = 8/9 * 1000
beat = beat/2
nodes = 50
stringnodes = 50
stripnodes = 300
steps = 16

generated_on = str(datetime.datetime.now())
headjson = {
    'version' : "2020.53",
    'author' : None,
    'author-email' : None,
    'author-website' : None,
    'song' : None,
    'artist' : None,
    'album' : None,
    'MusicURL' : None,
    'comment' : None,
    'sequenceTiming' : '25 ms',
    'sequenceType' : 'Media',
    'mediaFile' : "C:\\Users\\doug\\Downloads\\02 - Candy Cane Lane.mp3",
    'sequenceDuration' : '212.386',
    'imageDir' : None
}
# Configure one attribute with set()
root = Element('xsequence')
root.set('BaseChannel',"0") 
root.set('ChanCtrlBasic',"0") 
root.set('ChanCtrlColor',"0")
root.set('FixedPointTiming',"1")
root.set('ModelBlending',"true")
head = SubElement(root, 'head')
for key in headjson:
    subel = SubElement(head,key)
    if not headjson[key] == None: subel.text = headjson[key]
subel = SubElement(root, 'nextid')
subel.text = "1"
subel = SubElement(root, 'Jukebox')
colorPalettes = [
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette2=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette5=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette8=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#00FFFF,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette3=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette7=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#8000FF,C_CHECKBOX_Palette8=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette4=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette1=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette2=1,C_CHECKBOX_Palette3=1,C_CHECKBOX_Palette4=1,C_CHECKBOX_Palette5=1,C_CHECKBOX_Palette6=1,C_CHECKBOX_Palette7=1,C_CHECKBOX_Palette8=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette1=1,C_CHECKBOX_Palette2=1',
    'C_BUTTON_Palette1=#FFFFFF,C_BUTTON_Palette2=#FF0000,C_BUTTON_Palette3=#00FF00,C_BUTTON_Palette4=#0000FF,C_BUTTON_Palette5=#FFFF00,C_BUTTON_Palette6=#000000,C_BUTTON_Palette7=#FF8000,C_BUTTON_Palette8=#FF00FF,C_CHECKBOX_Palette2=1,C_CHECKBOX_Palette3=1'
]
colorsub = SubElement(root, 'ColorPalettes')
for palette in colorPalettes:
    SubElement(colorsub, "ColorPalette").text = palette
effectdb = SubElement(root, 'EffectDB' )
effectlist = [
    '',
    'E_CHECKBOX_Lines_FadeTrails=1,E_SLIDER_Lines_Objects=7,E_SLIDER_Lines_Segments=2,E_SLIDER_Lines_Speed=2,E_SLIDER_Lines_Thickness=1,E_SLIDER_Lines_Trails=0',
    'E_CHECKBOX_Shockwave_Blend_Edges=1,E_NOTEBOOK_Shockwave=Position,E_SLIDER_Shockwave_Accel=0,E_SLIDER_Shockwave_CenterX=35,E_SLIDER_Shockwave_CenterY=35,E_SLIDER_Shockwave_End_Radius=10,E_SLIDER_Shockwave_End_Width=50,E_SLIDER_Shockwave_Start_Radius=2,E_SLIDER_Shockwave_Start_Width=5',
    'E_CHECKBOX_Lines_FadeTrails=1,E_SLIDER_Lines_Objects=2,E_SLIDER_Lines_Segments=3,E_SLIDER_Lines_Speed=1,E_SLIDER_Lines_Thickness=1,E_SLIDER_Lines_Trails=0',
    'E_CHECKBOX_Marquee_PixelOffsets=0,E_CHECKBOX_Marquee_Reverse=1,E_CHECKBOX_Marquee_WrapX=0,E_CHECKBOX_Marquee_WrapY=0,E_NOTEBOOK_Marquee=Settings,E_SLIDER_MarqueeXC=0,E_SLIDER_MarqueeYC=0,E_SLIDER_Marquee_Band_Size=14,E_SLIDER_Marquee_ScaleX=100,E_SLIDER_Marquee_ScaleY=100,E_SLIDER_Marquee_Skip_Size=0,E_SLIDER_Marquee_Speed=8,E_SLIDER_Marquee_Stagger=0,E_SLIDER_Marquee_Start=0,E_SLIDER_Marquee_Thickness=52',
    'E_SLIDER_Life_Count=200,E_SLIDER_Life_Seed=0,E_SLIDER_Life_Speed=2',
    'E_CHECKBOX_Lines_FadeTrails=1,E_SLIDER_Lines_Objects=10,E_SLIDER_Lines_Segments=5,E_SLIDER_Lines_Speed=2,E_SLIDER_Lines_Thickness=1,E_SLIDER_Lines_Trails=0'
]
for effectitem in effectlist:
    effect = SubElement(effectdb, 'Effect')
    effect.text = effectitem
dljson = {
    'lor_params' : "596", 
    'channel_offset' : "0", 
    'num_channels' : "0", 
    'num_frames' : "0", 
    'data' : "&lt;rendered: erase-mode&gt;",
    'source' : "&lt;auto-generated&gt;",
    'name' : "Nutcracker"
}
root.append(Element('DataLayers', dljson))
displayeljson = [
    {'collapsed':"0", 'type':"timing", 'name':"New Timing", 'visible':"1", 'views':"Master View", 'active':"1" },
    {'collapsed':"0", 'type':"model", 'name':"Tree", 'visible':"1"},
    {'collapsed':"0", 'type':"model", 'name':"String", 'visible':"1"},
    {'collapsed':"0", 'type':"model", 'name':"Strip", 'visible':"1"}
]
displayel = SubElement(root, 'DisplayElements' )
for delitem in displayeljson:
    displayel.append(Element('Element', delitem))
eleffects = SubElement(root, 'ElementEffects' )
effectjson = {
    'Tree' : {
        'attrib' : { 'type': "model", 'name': "Tree" },
        'EffectLayer': [],
        'Node': {}
    },
    'String' : {
        'attrib' : { 'type': "model", 'name': "String" },
        'EffectLayer': [],
        'Node': {}
    },
    'Strip' : {
        'attrib' : { 'type': "model", 'name': "Strip" },
        'EffectLayer': [],
        'Node': {}
    },
}
# Show stuff
#########################################################################
currtime = 0
layer = 'String'
# slow lead up ##########################################################
for i in range(stringnodes):
    stepid = 0
    steps = 12
    nodecnt = stringnodes/steps
    group = int(i/nodecnt)
    for x in range(steps):
        palette = "0"
        nodecnt = nodes/steps
        if not group % 2 == x % 2: palette = "7"
        if i <= int(round(nodecnt*(x+1))):
            nname = "On"
        else:
            nname = "Off"
        starttime = int(round(x*beat))+currtime
        endtime = int(round((x+1)*beat))+currtime
        if nname == 'On':
            if not i in effectjson[layer]['Node']: effectjson[layer]['Node'][i] = []
            effectitem = {'ref': '0', 'name':nname, 'startTime': str(starttime), 'endTime':str(endtime), 'palette':str(palette)}    
            effectjson[layer]['Node'][i].append( effectitem )
        stepid = stepid + 1
currtime = int(round((steps)*beat))+currtime

# lead up final #########################################################
steps = 4
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"4", 'name':"Marquee", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "9" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Random Cycle ##########################################################
steps = 24
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"5", 'name':"Life", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "8" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# First Speed Up ########################################################
steps = 4
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"4", 'name':"Marquee", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "9" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Random Cycle ##########################################################
steps = 24
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"5", 'name':"Life", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "8" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Second Speed Up #######################################################
steps = 4
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"4", 'name':"Marquee", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "9" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Color Cycle ###########################################################
steps = 7
layer = 'String'
for x in range(steps):
    starttime = int(round(x*beat))+currtime
    endtime = int(round((x+1)*beat))+currtime
    effectitem = { 'ref':"0", 'name':"On", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': str(x) }
    effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Waiting for you #######################################################
steps = 8
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"6", 'name':"Lines", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "10" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Color Cycle ###########################################################
steps = 7
layer = 'String'
for x in range(steps):
    starttime = int(round(x*beat))+currtime
    endtime = int(round((x+1)*beat))+currtime
    effectitem = { 'ref':"0", 'name':"On", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': str(x) }
    effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime

# Waiting for you #######################################################
steps = 8
layer = 'String'
starttime = int(round(0*beat))+currtime
endtime = int(round((steps)*beat))+currtime
effectitem = { 'ref':"6", 'name':"Lines", 'startTime': str(starttime), 'endTime': str(endtime), 'palette': "10" }
effectjson[layer]['EffectLayer'].append( effectitem )
currtime = int(round((steps)*beat))+currtime


#print( json.dumps(effectjson, indent=2) )
eleffects = SubElement(root, 'ElementEffects' )
for key in effectjson.keys():
    myelement = Element( 'Element', effectjson[key]['attrib'] )
    elelement = Element( 'EffectLayer', {} )
    x = 0
    for index, item in enumerate(effectjson[key]['EffectLayer']):
        item['id'] = str(index)
        elelement.append(Element('Effect',item))
    myelement.append(elelement)
    stelement = Element('Strand', {'index':'0'})
    for subkey in effectjson[key]['Node'].keys():
        nodeelement = Element('Node', {'index': str(subkey)})
        for index, item in enumerate(effectjson[key]['Node'][subkey]):
            item['id'] = str(index)
            nodeelement.append(Element('Effect',item))
        stelement.append(nodeelement)
    myelement.append(stelement)
    #print(tostring(myelement))
    eleffects.append(myelement)
    
#########################################################################
  
for delitem in displayeljson:
    myname = {}
    myname['name'] = delitem['name']
    myname['type'] = delitem['type']
    #myeleffect = Element('Element',myname)
    #SubElement(myeleffect, 'EffectLayer' )
    #eleffects.append(myeleffect)
    if delitem['name'] == 'Tacos':
        strandel = Element('Strand',{'index':'0'})
        nodejson = {}
        nodejson['model'] = 'String'
        endtime=0
        for i in range(nodes):
            stepid = 0
            steps = 12
            nodecnt = nodes/steps
            group = int(i/nodecnt)
            nodeel = Element('Node', {'index': str(i)})
            starttime = 0
            steps = 4
            starttime = endtime
            for x in range(steps):
                timestart = int(round(x*beat))+starttime
                endtime = int(round((x+1)*beat))+starttime
                if x % 2 == 1:
                    palette = "0"
                else:
                    palette = "7"
                nname = "On"
                effectson = {'ref': '0', 'name':nname, 'id': str(stepid), 'startTime': str(timestart), 'endTime':str(endtime), 'palette':str(palette)}
                stepid = stepid + 1
                nodeel.append(Element('Effect',effectson))
            steps = 24
            starttime = endtime
            for x in range(steps):
                timestart = int(round(x*beat))+starttime
                endtime = int(round((x+1)*beat))+starttime
                palette = str(random.randint(0,7))
                nname = "On"
                effectson = {'ref': '0', 'name':nname, 'id': str(stepid), 'startTime': str(timestart), 'endTime':str(endtime), 'palette':str(palette)}
                stepid = stepid + 1
                nodeel.append(Element('Effect',effectson))
            steps = 4
            starttime = endtime
            for x in range(steps):
                timestart = int(round(x*beat))+starttime
                endtime = int(round((x+1)*beat))+starttime
                if x % 2 == 1:
                    palette = "7"
                else:
                    palette = "0"
                nname = "On"
                effectson = {'ref': '0', 'name':nname, 'id': str(stepid), 'startTime': str(timestart), 'endTime':str(endtime), 'palette':str(palette)}
                stepid = stepid + 1
                nodeel.append(Element('Effect',effectson))
            steps = 7
            starttime = endtime
            for x in range(steps):
                timestart = int(round(x*beat*2))+starttime
                endtime = int(round((x+1)*beat*2))+starttime
                palette = str(x)
                nname = "On"
                effectson = {'ref': '0', 'name':nname, 'id': str(stepid), 'startTime': str(timestart), 'endTime':str(endtime), 'palette':str(palette)}
                stepid = stepid + 1
                nodeel.append(Element('Effect',effectson))
            strandel.append(nodeel)
        myeleffect.append(strandel)
subel = SubElement(root,'lastView')
subel.text = '0'
subel = SubElement(root,'TimingTags')
for i in range(10):
    subel.append(Element('Tag',{'number': str(i), 'position': "-1"}))
    


rough_string = ElementTree.tostring(root, 'utf-8')
reparsed = xdom.parseString(rough_string)
fileout = open('..\\xLights\\xmloutput.xsq','w')
fileout.write(reparsed.toprettyxml(indent=" "))
fileout.close()
#print(tostring(root, pretty_print=True) )
